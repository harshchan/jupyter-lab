# %%
for i in range (0,9):
    print("\n ",i)
# Out:
#   0
#
#   1
#
#   2
#
#   3
#
#   4
#
#   5
#
#   6
#
#   7
#
#   8

# %%
for i in range(9):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
animal="hippo"
for i in animal:
    print(i)
# Out:
# h
# i
# p
# p
# o

# %%
sports=["football","cricket","basketball","volleyball"]
for x in sports:
    print(x)
# Out:
# football
# cricket
# basketball
# volleyball

# %%
for i in range (5):
    if x==2:
        pass
    else:
        print(i)
